# %% [markdown]
# <a href="https://colab.research.google.com/github/hamedali70/Hamed_rl_sem8/blob/main/RL_Exp_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hamed Ali | 15 | 211A013

# %% [markdown]
# ##Exp 5 - Implementing Monte carlo control and Temporal Difference (TD) learning Algorithm

# %%
print("Hamed Ali - 211A013")
import numpy as np
import random
# Out:
# Hamed Ali - 211A013

# %%
print("Hamed Ali - 211A013")

class GridWorld:
  def __init__(self,size =4 ,start=(0,0),goal=(3,3)):
    self.size=size
    self.start=start
    self.goal=goal
    self.state=start
    self.actions=[(0,1),(1,0),(0,-1),(-1,0)]  #Right,down,left ,up

  def reset(self):
    self.state=self.start
    return self.state

  def step (self,action):
    next_state = (self.state[0]+self.actions[action][0],
                  self.state[1]+self.actions [action][1])

    if 0<= next_state[0]< self.size and 0 <= next_state[1] <self.size:
      self.state = next_state
      reward =1 if self.state ==self.goal else -0.1
      done = self.state ==self.goal
      return self.state,reward,done
    else:
      # If the move is invalid, the state doesn't change, apply a penalty, and it's not done.
      reward = -1 # Penalty for hitting a wall
      done = False
      return self.state, reward, done
# Out:
# Hamed Ali - 211A013

# %% [markdown]
# #2. Monte carlo control with exploring starts

# %%
print("Hamed Ali - 211A013")

def monte_carlo_control (env,episodes=5000,gamma=0.9,epilson=0.1):
 Q={((i,j), a): 0 for i in range (env.size) for j in range (env.size)
 for a in range (4)}
 returns = {((i,j), a): [] for i in range (env.size) for j in range (env.size)
 for a in range (4)}

 for _ in range(episodes):
  state = env.reset()
  episode = []

  while True:
    # Choose action using epsilon-greedy policy derived from Q
    if random.random() < epilson:
        action = random.choice(range(4))
    else:
        action = max(range(4), key=lambda a_val: Q[(state, a_val)])

    next_state, reward, done = env.step(action)
    episode.append((state, action, reward))
    state = next_state
    if done:
      break

  G = 0
  # Iterate through the episode in reverse to calculate returns
  for state_t, action_t, reward_t in reversed(episode):
    G = gamma * G + reward_t
    # Check if (state, action) pair has been visited for the first time in this episode
    first_occurrence = True
    for s, a, _ in episode[:episode.index((state_t, action_t, reward_t))]: # corrected slicing
        if s == state_t and a == action_t:
            first_occurrence = False
            break
    if first_occurrence:
        returns[(state_t, action_t)].append(G)
        Q[(state_t, action_t)] = np.mean(returns[(state_t, action_t)])

 return Q
# Out:
# Hamed Ali - 211A013

# %% [markdown]
# #3.SARSA (State-Action-Reward-State)

# %%
print("Hamed Ali - 211A013")

#Temporal difference learning algorithm (SARSA)
def sarsa (env,episodes=5000,gamma=0.9,alpha=0.1,epilson =0.1):
  Q={((i,j), a): 0 for i in range (env.size) for j in range (env.size)
  for a in range (4)}

  for _ in range(episodes):
    state = env.reset()
    action = random.choice(range(4)) if random.random() < epilson else max(range(4), key=lambda a_val: Q[(state, a_val)])
    while True:
      next_state, reward, done = env.step(action)
      next_action = random.choice(range(4)) if random.random() < epilson else max(range(4) , key=lambda a: Q[(next_state, a)])

      Q[(state, action)] += alpha * (reward + gamma * Q[(next_state, next_action)] - Q[(state, action)])
      state,action = next_state,next_action
      if done:
        break
  return Q
#
# Out:
# Hamed Ali - 211A013

# %% [markdown]
# Q- Learning is very similar to SARSA but uses max feature Q -value instead of followig the policy

# %% [markdown]
# #4.Q Learning Algotrithm

# %%
print("Hamed Ali - 211A013")

#Q-Learning algorithm
def q_learning(env,episodes=5000,gamma=0.9,alpha=0.1,epilson=0.1):
  Q={((i,j), a): 0 for i in range (env.size) for j in range (env.size)
  for a in range (4)}

  for _ in range(episodes):
    state = env.reset()

    while True:
      action = random.choice(range(4)) if random.random() < epilson else max(range(4), key=lambda a: Q[(state, a)])
      next_state, reward, done = env.step(action)
      # Q-learning update: uses max over next actions
      Q[(state, action)] += alpha * (reward + gamma * max(Q[(next_state, a)] for a in range(4)) - Q[(state, action)])
      state = next_state
      if done:
        break
  return Q
# Out:
# Hamed Ali - 211A013

# %% [markdown]
# #5.Running the training

# %%
print("Hamed Ali - 211A013")

#Initialize Environment
env = GridWorld()

#Train with Monte Carlo
Q_mc = monte_carlo_control(env)

#Train with SARSA
Q_sarsa = sarsa(env)

#Train with Q_Learning
Q_qlearning = q_learning(env)
# Out:
# Hamed Ali - 211A013

# %% [markdown]
# #6. Sample Q -Values

# %%
print("Hamed Ali - 211A013")

#print
print("Sample Q-values from Monte Carlo:",{k : Q_mc[k] for k in list(Q_mc.keys())[:20]})
print("Sample Q-value from SARSA:",{k : Q_sarsa[k] for k in list(Q_sarsa.keys())[:20]})
print("Sample Q-values from Q-Learning:",{k : Q_qlearning[k] for k in list(Q_qlearning.keys())[:20]})
# Out:
# Hamed Ali - 211A013
# Sample Q-values from Monte Carlo: {((0, 0), 0): np.float64(0.02689196528598072), ((0, 0), 1): np.float64(0.04433931725191933), ((0, 0), 2): np.float64(-1.2157904104557462), ((0, 0), 3): np.float64(-2.753786110795835), ((0, 1), 0): np.float64(-0.9100430078504842), ((0, 1), 1): np.float64(0.227068237647059), ((0, 1), 2): np.float64(-0.08326427499999994), ((0, 1), 3): np.float64(-0.7190199999999999), ((0, 2), 0): np.float64(-6.067943684120751), ((0, 2), 1): np.float64(0.11642048900000013), ((0, 2), 2): np.float64(0.16058125454545466), ((0, 2), 3): 0, ((0, 3), 0): np.float64(-9.046758213060118), ((0, 3), 1): np.float64(-3.7939558917068688), ((0, 3), 2): np.float64(-2.7165225139300584), ((0, 3), 3): np.float64(-9.120146434616649), ((1, 0), 0): np.float64(0.2150452005055041), ((1, 0), 1): np.float64(0.19528134525781723), ((1, 0), 2): np.float64(-0.941039116975401), ((1, 0), 3): np.float64(-0.14979713865739674)}
# Sample Q-value from SARSA: {((0, 0), 0): 0.05250313423385784, ((0, 0), 1): 0.1148630474025369, ((0, 0), 2): -0.9377955874060079, ((0, 0), 3): -0.989992510133818, ((0, 1), 0): 0.14210393642906743, ((0, 1), 1): 0.23575701661074697, ((0, 1), 2): -0.10152215850070258, ((0, 1), 3): -0.7850120221345924, ((0, 2), 0): -0.05433884485992464, ((0, 2), 1): 0.37374140498890346, ((0, 2), 2): -0.11398651267556371, ((0, 2), 3): -0.5196527905892204, ((0, 3), 0): -0.19, ((0, 3), 1): 0.2279244168503074, ((0, 3), 2): -0.03280447880184602, ((0, 3), 3): -0.19090000000000001, ((1, 0), 0): 0.24158734418486325, ((1, 0), 1): 0.1217251517837437, ((1, 0), 2): -0.84593927877553, ((1, 0), 3): -0.08857953507616931}
# Sample Q-values from Q-Learning: {((0, 0), 0): 0.1809799999999987, ((0, 0), 1): 0.18097923168219932, ((0, 0), 2): -0.8371179191291926, ((0, 0), 3): -0.8371176248505874, ((0, 1), 0): 0.31219204442428594, ((0, 1), 1): 0.3121999999999987, ((0, 1), 2): 0.06288195711205619, ((0, 1), 3): -0.7190192776554978, ((0, 2), 0): -0.05159625964755357, ((0, 2), 1): 0.4579996189931884, ((0, 2), 2): 0.04001320619588984, ((0, 2), 3): -0.4410406112392634, ((0, 3), 0): -0.1, ((0, 3), 1): -0.0341920612, ((0, 3), 2): 0.1454414718179348, ((0, 3), 3): -0.1, ((1, 0), 0): 0.31219999999654174, ((1, 0), 1): 0.18883873004813503, ((1, 0), 2): -0.46345659631634356, ((1, 0), 3): -0.04599995421555326}
